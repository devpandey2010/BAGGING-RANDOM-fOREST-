# %%
#Multiple model training,Pipeline and column Transformer

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df=sns.load_dataset("tips")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#predict what is the time?  if any one is visting ...is it lunch or dinner? time is the target varible
df.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
#EDA
#data preparation >>encoding ,missing value treatement,scaling
#now we wiil automate this data preparartion using pipeline and column transfer

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#since time is nominal variable, the we will use label encoder
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["time"]=encoder.fit_transform(df["time"])

# %%
df["time"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    0
# 240    0
# 241    0
# 242    0
# 243    0
# Name: time, Length: 244, dtype: int64

# %%
df["time"].unique() #lunch>>0,dinner>>1
# Out:
# array([0, 1])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day  time  size
# 0         16.99  1.01  Female     No   Sun     0     2
# 1         10.34  1.66    Male     No   Sun     0     3
# 2         21.01  3.50    Male     No   Sun     0     3
# 3         23.68  3.31    Male     No   Sun     0     2
# 4         24.59  3.61  Female     No   Sun     0     4
# ..          ...   ...     ...    ...   ...   ...   ...
# 239       29.03  5.92    Male     No   Sat     0     3
# 240       27.18  2.00  Female    Yes   Sat     0     2
# 241       22.67  2.00    Male    Yes   Sat     0     2
# 242       17.82  1.75    Male     No   Sat     0     2
# 243       18.78  3.00  Female     No  Thur     0     2
#
# [244 rows x 7 columns]

# %%
x=df.drop("time",axis=1)
y=df["time"]
x
# Out:
#      total_bill   tip     sex smoker   day  size
# 0         16.99  1.01  Female     No   Sun     2
# 1         10.34  1.66    Male     No   Sun     3
# 2         21.01  3.50    Male     No   Sun     3
# 3         23.68  3.31    Male     No   Sun     2
# 4         24.59  3.61  Female     No   Sun     4
# ..          ...   ...     ...    ...   ...   ...
# 239       29.03  5.92    Male     No   Sat     3
# 240       27.18  2.00  Female    Yes   Sat     2
# 241       22.67  2.00    Male    Yes   Sat     2
# 242       17.82  1.75    Male     No   Sat     2
# 243       18.78  3.00  Female     No  Thur     2
#
# [244 rows x 6 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 239    0
# 240    0
# 241    0
# 242    0
# 243    0
# Name: time, Length: 244, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
#       tip     sex smoker   day  time  size
# 0    1.01  Female     No   Sun     0     2
# 154  2.00    Male     No   Sun     0     4
# 167  4.50    Male     No   Sun     0     4
# 110  3.00    Male     No   Sat     0     2
# 225  2.50  Female    Yes   Fri     1     2
# ..    ...     ...    ...   ...   ...   ...
# 137  2.00  Female     No  Thur     1     2
# 72   3.14  Female    Yes   Sat     0     2
# 140  3.50  Female     No  Thur     1     2
# 235  1.25    Male     No   Sat     0     2
# 37   3.07  Female     No   Sat     0     3
#
# [195 rows x 6 columns]

# %%
#handling the missing value
#data encoding
#featuer scaling

from sklearn.impute import SimpleImputer #for missing value treatment
from sklearn.preprocessing import OneHotEncoder #for encoding
from sklearn.preprocessing import StandardScaler  #for scaling


from sklearn.pipeline import Pipeline # give the sequence of data transformer
from sklearn.compose import ColumnTransformer #grops all the pipeline steps for each of the columns

# %%
df.sample(1) #return the random sample
# Out:
#      total_bill   tip   sex smoker  day  time  size
# 235       10.07  1.25  Male     No  Sat     0     2

# %%
categorical_cols=["sex","smoker","day"]
numerical_cols=["total_bill","tip","size"]

# %%
#feature engennering automation using pipeline and column tranformer
#numerical pipeline
num_pipeline=Pipeline(steps=[("imputation",SimpleImputer(strategy="median")),("scaling",StandardScaler())])
#categorical pipleine
cat_pipeline=Pipeline(steps=[("imputation",SimpleImputer(strategy="most_frequent")),("encoding",OneHotEncoder())])

# %%
preprocessor=ColumnTransformer([("num_pipeline",num_pipeline,numerical_cols),("cat_pipeline",cat_pipeline,categorical_cols)])

# %%
x_train=preprocessor.fit_transform(x_train)
x_test=preprocessor.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-a373dc09b365> in <cell line: 0>()
# ----> 1 x_train=preprocessor.fit_transform(x_train)
#       2 x_test=preprocessor.transform(x_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %%
x_train
# Out:
# array([[-0.28611937, -1.47443803, -0.57766863, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.02695905, -0.71612531,  1.47042924, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.3716196 ,  1.19880579,  1.47042924, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.23206267,  0.43283335, -0.57766863, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.06543688, -1.29060464, -0.57766863, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.29287646,  0.1034652 ,  0.44638031, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
x_test
# Out:
# array([[-1.85376383, -1.48209775, -1.60171757,  1.        ,  0.        ,
#          0.        ,  1.        ,  0.        ,  1.        ,  0.        ,
#          0.        ],
#        [-0.08453291,  0.04984713, -0.57766863,  1.        ,  0.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          1.        ],
#        [ 0.79501474,  0.36389583,  0.44638031,  0.        ,  1.        ,
#          0.        ,  1.        ,  0.        ,  1.        ,  0.        ,
#          0.        ],
#        [-0.59356688, -0.33313909, -0.57766863,  0.        ,  1.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          1.        ],
#        [ 0.18349826,  0.04984713, -0.57766863,  0.        ,  1.        ,
#          1.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          1.        ],
#        [-1.32783714, -1.14506988, -0.57766863,  0.        ,  1.        ,
# ...

# %%
#now data is ready and you want to build the multiple models
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
models={"support vector classifier":SVC(),
        "Decision tree":DecisionTreeClassifier(),
        "Logistic Regression":LogisticRegression(),
        "RandomForest":RandomForestClassifier()}
models
# Out:
# {'support vector classifier': SVC(),
#  'Decision tree': DecisionTreeClassifier(),
#  'Logistic Regression': LogisticRegression(),
#  'RandomForest': RandomForestClassifier()}

# %%
from sklearn.metrics import accuracy_score

def model_train_eval(x_train,x_test,y_train,y_test,models):
  evaluation={}
  for i in range(len(models)):
    model=list(models.values())[i]
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    model_score=accuracy_score(y_test,y_pred)
    evaluation[list(models.keys())[i]]=model_score
  return evaluation

# %%
model_train_eval(x_train,x_test,y_train,y_test,models)
# Out:
# {'support vector classifier': 0.9183673469387755,
#  'Decision tree': 0.8979591836734694,
#  'Logistic Regression': 0.9183673469387755,
#  'RandomForest': 0.8979591836734694}

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf
# Out:
# RandomForestClassifier()

# %%
x_train,x_test
# Out:
# (array([[-0.28611937, -1.47443803, -0.57766863, ...,  0.        ,
#           1.        ,  0.        ],
#         [ 0.02695905, -0.71612531,  1.47042924, ...,  0.        ,
#           1.        ,  0.        ],
#         [ 1.3716196 ,  1.19880579,  1.47042924, ...,  0.        ,
#           1.        ,  0.        ],
#         ...,
#         [-0.23206267,  0.43283335, -0.57766863, ...,  0.        ,
#           0.        ,  1.        ],
#         [-1.06543688, -1.29060464, -0.57766863, ...,  1.        ,
#           0.        ,  0.        ],
#         [-0.29287646,  0.1034652 ,  0.44638031, ...,  1.        ,
#           0.        ,  0.        ]]),
#  array([[-1.85376383, -1.48209775, -1.60171757,  1.        ,  0.        ,
#           0.        ,  1.        ,  0.        ,  1.        ,  0.        ,
#           0.        ],
#         [-0.08453291,  0.04984713, -0.57766863,  1.        ,  0.        ,
#           1.        ,  0.        ,  0.        ,  0.        ,  0.        ,
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
params={'max_depth':[1,2,3,4,5,10,None],'n_estimators':[30,40,50,100,200,300],
        "criterion":['gini','entropy']}

# %%
clf=RandomizedSearchCV(rf,param_distributions=params,cv=5,verbose=3,scoring="accuracy",n_iter=10)
clf
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 4, 5, 10, None],
#                                         'n_estimators': [30, 40, 50, 100, 200,
#                                                          300]},
#                    scoring='accuracy', verbose=3)

# %%
clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=0.923 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=0.974 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=1.000 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, n_estimators=50;, score=1.000 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.923 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=1, n_estimators=100;, score=0.897 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=1, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=1, n_estimators=100;, score=1.000 total time=   0.2s
# ...

# %%
clf.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 2, 'criterion': 'entropy'}

# %%
clf.best_score_
# Out:
# np.float64(0.9794871794871796)

# %%
y_pred=clf.best_estimator_.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9183673469387755
